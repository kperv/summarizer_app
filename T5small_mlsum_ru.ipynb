# %% [markdown]
# <a href="https://colab.research.google.com/github/kperv/summarizer_app/blob/main/T5small_mlsum_ru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Summarization project
# ### for ods.ai Natural Language Processing course
#
# Pretrained language model **t5-small**
# (60 million parameters)
#
# https://arxiv.org/abs/1910.10683
#
# https://github.com/google-research/text-to-text-transfer-transformer
#
# **Dataset** is the russian part of the Large-scale MultiLingual SUMmarization dataset.
#
# Splits:
#
# -Train -- Val -- Test
#
# 25556  - 750 - 757
#
# https://github.com/ThomasScialom/MLSUM
#
# The project is based on the official **hf.co tutorial**
#
# https://github.com/huggingface/notebooks/blob/master/examples/summarization.ipynb

# %%
# %%capture
! pip install datasets nltk torch
! pip install rouge==0.3.1
! pip install -U transformers

# %%
# !nvidia-smi
# Out:
# Tue Dec 14 08:06:40 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import nltk
import numpy as np
import pandas as pd
import torch
import transformers
from datasets import DatasetDict
from datasets import Dataset
from datasets import load_dataset
from rouge import Rouge

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Fine-tuning a model on a summarization task

# %% [markdown]
# ### Loading the dataset

# %%
dataset = load_dataset("mlsum", 'ru')
# Out:
# Downloading:   0%|          | 0.00/1.59k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Downloading and preparing dataset mlsum/ru (download: 101.30 MiB, generated: 263.38 MiB, post-processed: Unknown size, total: 364.68 MiB) to /root/.cache/huggingface/datasets/mlsum/ru/1.0.0/77f23eb185781f439927ac2569ab1da1083195d8b2dab2b2f6bbe52feb600688...
#   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/99.0M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.51M [00:00<?, ?B/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset mlsum downloaded and prepared to /root/.cache/huggingface/datasets/mlsum/ru/1.0.0/77f23eb185781f439927ac2569ab1da1083195d8b2dab2b2f6bbe52feb600688. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'summary', 'topic', 'url', 'title', 'date'],
#         num_rows: 25556
#     })
#     validation: Dataset({
#         features: ['text', 'summary', 'topic', 'url', 'title', 'date'],
#         num_rows: 750
#     })
#     test: Dataset({
#         features: ['text', 'summary', 'topic', 'url', 'title', 'date'],
#         num_rows: 757
#     })
# })

# %% [markdown]
# ### Preprocessing the data

# %%
model_checkpoint = "t5-small"

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/231M [00:00<?, ?B/s]

# %%
max_input_length = 1024
max_target_length = 128


def preprocess_function(examples):
    inputs = ["summarize: " + doc for doc in examples["text"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["summary"], max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_datasets = dataset.map(preprocess_function, batched=True)
# Out:
#   0%|          | 0/26 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# ### Fine-tuning the model

# %%
from transformers import DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

device = torch.device("cuda")
model.to(device)

# %%
batch_size = 4
model_name = model_checkpoint.split("/")[-1]
args = Seq2SeqTrainingArguments(
    f"{model_name}-mlsum-ru",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=5,
    predict_with_generate=True,
    fp16=True,
    logging_dir='logs',
)

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %%
def compute_metrics(eval_pred):
    rouge = Rouge()
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    decoded_preds = [nltk.sent_tokenize(pred.strip()) for pred in decoded_preds]
    decoded_labels = [nltk.sent_tokenize(label.strip()) for label in decoded_labels]
    
    decoded_preds = [pred if len(pred) else 'а' for pred in decoded_preds]
    decoded_labels = [label if len(label) else 'а' for label in decoded_labels]


    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(pred) for pred in decoded_preds]
    decoded_labels = ["\n".join(label) for label in decoded_labels]
    
    result = rouge.get_scores(hyps=decoded_preds, refs=decoded_labels, avg=True)
    # Extract a few results
    result = {key: value['f'] * 100 for key, value in result.items()}
    
    return {k: round(v, 4) for k, v in result.items()}

# %%
trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# Using amp half precision backend

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: url, summary, topic, title, date, text.
# ***** Running training *****
#   Num examples = 25556
#   Num Epochs = 5
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 31945
#     <div>
#
#       <progress value='11469' max='31945' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11469/31945 4:11:16 < 7:28:41, 0.76 it/s, Epoch 1.79/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge-1</th>
#       <th>Rouge-2</th>
#       <th>Rouge-l</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.213500</td>
#       <td>2.185042</td>
#       <td>2.658900</td>
#       <td>0.287100</td>
#       <td>1.847200</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-500
# Configuration saved in t5-small-mlsum-ru/checkpoint-500/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-500/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-1000
# Configuration saved in t5-small-mlsum-ru/checkpoint-1000/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-1500
# Configuration saved in t5-small-mlsum-ru/checkpoint-1500/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-2000
# Configuration saved in t5-small-mlsum-ru/checkpoint-2000/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-2000/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-2500
# Configuration saved in t5-small-mlsum-ru/checkpoint-2500/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-2500/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-3000
# Configuration saved in t5-small-mlsum-ru/checkpoint-3000/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-3000/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-3500
# Configuration saved in t5-small-mlsum-ru/checkpoint-3500/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-3500/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-4000
# Configuration saved in t5-small-mlsum-ru/checkpoint-4000/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-4000/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-4500
# Configuration saved in t5-small-mlsum-ru/checkpoint-4500/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-4500/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-5000
# Configuration saved in t5-small-mlsum-ru/checkpoint-5000/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-5000/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-5500
# Configuration saved in t5-small-mlsum-ru/checkpoint-5500/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-5500/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-6000
# Configuration saved in t5-small-mlsum-ru/checkpoint-6000/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-6000/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-4500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: url, summary, topic, title, date, text.
# ***** Running Evaluation *****
#   Num examples = 750
#   Batch size = 4
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-6500
# Configuration saved in t5-small-mlsum-ru/checkpoint-6500/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-6500/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-7000
# Configuration saved in t5-small-mlsum-ru/checkpoint-7000/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-7000/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-5500] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-7500
# Configuration saved in t5-small-mlsum-ru/checkpoint-7500/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-7500/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-8000
# Configuration saved in t5-small-mlsum-ru/checkpoint-8000/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-8000/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-8500
# Configuration saved in t5-small-mlsum-ru/checkpoint-8500/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-8500/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-9000
# Configuration saved in t5-small-mlsum-ru/checkpoint-9000/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-9000/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-7500] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-9500
# Configuration saved in t5-small-mlsum-ru/checkpoint-9500/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-9500/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-8000] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-10000
# Configuration saved in t5-small-mlsum-ru/checkpoint-10000/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-10000/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-8500] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-10500
# Configuration saved in t5-small-mlsum-ru/checkpoint-10500/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-10500/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to t5-small-mlsum-ru/checkpoint-11000
# Configuration saved in t5-small-mlsum-ru/checkpoint-11000/config.json
# Model weights saved in t5-small-mlsum-ru/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in t5-small-mlsum-ru/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in t5-small-mlsum-ru/checkpoint-11000/special_tokens_map.json
# Deleting older checkpoint [t5-small-mlsum-ru/checkpoint-9500] due to args.save_total_limit

# %% [markdown]
# ### Get model predictions

# %%
predictions = trainer.predict(tokenized_datasets["test"])

# %%
summaries = tokenizer.batch_decode(predictions.predictions, skip_special_tokens=True)

# %%
dataset['test'].set_format('pandas')
test_df = dataset['test'][:]
test_df = test_df.drop(columns=['summary'])
test_df['summary'] = summaries
test_df.head(5)

# %% [markdown]
# ### Calculate Rouge scores

# %%
def get_rouge_score(sample):
    rouge = Rouge()
    preprocess_exs = lambda exs : [ex.strip().lower() for ex in exs]
    predictions = []
    predictions.append(sample['summary'])
    predictions = preprocess_exs(predictions)
    references = []
    references.append(sample.text)
    references = preprocess_exs(references)
    predictions = [pred if len(pred) else 'а' for pred in predictions]
    rouge_scores =  rouge.get_scores(predictions, references, avg=True)
    return {k: round(v['f'], 3) for k, v in rouge_scores.items()}

# %%
def add_metrics(dataset):
    dataset = dataset.loc[:, ['text', 'summary']]
    dataset[['rouge-1', 'rouge-2', 'rouge-l']] = 0, 0, 0
    df = pd.DataFrame(list(dataset.apply(get_rouge_score, axis=1).values))
    dataset = df.combine_first(dataset)
    dataset = dataset.reindex(
        columns=['text', 'summary', 'rouge-1', 'rouge-2', 'rouge-l']
    )
    return dataset

# %%
test_df = add_metrics(test_df)
test_df.head()

# %%
round(test_df['rouge-1'].mean(), 3)

# %%
round(test_df['rouge-2'].mean(), 3)

# %%
round(test_df['rouge-l'].mean(), 3)
